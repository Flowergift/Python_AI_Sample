# %% [markdown]
# <a href="https://colab.research.google.com/github/Flowergift/Python_AI_Sample/blob/main/424_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

NUM_SAMPLES = 1000

np.random.seed(int(time.time()))
ps = np.random.uniform(-6, 2, NUM_SAMPLES)
es = 0.5*(ps+2)**2

plt.plot(ps, es, '.b')
plt.show()

p = -5
E = 0.5*(p+2)**2
lr = 0.5


for i in range(16):
  DpE = p+2
  p = p - lr*DpE
  print('p:',p)
# Out:
# p: -3.5
# p: -2.75
# p: -2.375
# p: -2.1875
# p: -2.09375
# p: -2.046875
# p: -2.0234375
# p: -2.01171875
# p: -2.005859375
# p: -2.0029296875
# p: -2.00146484375
# p: -2.000732421875
# p: -2.0003662109375
# p: -2.00018310546875
# p: -2.000091552734375
# p: -2.0000457763671875
