# %% [markdown]
# <a href="https://colab.research.google.com/github/Flowergift/Python_AI_Sample/blob/main/424_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

NUM_SAMPLES = 1000

np.random.seed(int(time.time()))
ps = np.random.uniform(-6, 2, NUM_SAMPLES)
es = 0.5*(ps+2)**2

plt.plot(ps, es, '.b')
plt.show()

p = 0
E = 0.5*(p+2)**2
lr = 0.5


for i in range(8):
  DpE = p+2
  p = p - lr*DpE
  print('p:',p)
# Out:
# p: -1.0
# p: -1.5
# p: -1.75
# p: -1.875
# p: -1.9375
# p: -1.96875
# p: -1.984375
# p: -1.9921875
